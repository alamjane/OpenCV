# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('C:/Data Science/cat.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (662, 1216, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB Folloows --> Red Green Blue
# OpenCV Follows --> Blue Green Red

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('C:/Data Science/cat.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='gray') # cmap --> color map

# %%
plt.imshow(img_gray, cmap='magma')

# %%
fix_img.shape
# Out:
# (662, 1216, 3)

# %%
new_img = cv2.resize(fix_img, (2000, 900))

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img,0)
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img,1)
plt.imshow(new_img)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
# Opening image files directly with OpenCV

import cv2

img = cv2.imread('C:/Data Science/cat.jpg')

cv2.imshow('cat',img)

cv2.waitKey()
# Out:
# -1
