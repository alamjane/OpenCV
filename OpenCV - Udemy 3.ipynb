# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread('C:/Data Science/bridge.jpeg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
img = cv2.imread('C:/Data Science/bridge.jpeg',0)
plt.imshow(img, cmap='gray')

# %%
img.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %%
# Image Thresholding 

ret,thresh1 = cv2.threshold(img,100,255, cv2.THRESH_BINARY)

# %% [raw]
# ret

# %%
plt.imshow(thresh1, cmap='gray')

# %%
img2 = cv2.imread('C:/Data Science/butterfly.jpeg')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

plt.imshow(img2)

# %%
img2 = cv2.imread('C:/Data Science/butterfly.jpeg',0)
plt.imshow(img2, cmap='gray')

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
ax.imshow(img2, cmap='gray')

# %%
ret,th1 = cv2.threshold(img2,100,255, cv2.THRESH_BINARY)
plt.imshow(th1, cmap='gray')
